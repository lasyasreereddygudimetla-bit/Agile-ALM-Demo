# %% [markdown]
# <a href="https://colab.research.google.com/github/lasyasreereddygudimetla-bit/Agile-ALM-Demo/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !npm install pptxgenjs
# !node CatalogIQ_UniHack_ppt_generator.js

pres.writeFile({ fileName: 'CatalogIQ_UniHack_Presentation.pptx' });

# %%
# %%writefile CatalogIQ_UniHack_ppt_generator.js
# const pptxgen = require("pptxgenjs");
#
# const NAVY = "0B2A5C";
# const NAVY_DARK = "0A2450";
# const BLUE = "1E88F5";
# const BLUE_LIGHT = "5FA8F7";
# const GRAY_TEXT = "3A3A3A";
# const LGRAY = "6B6B6B";
# const WHITE = "FFFFFF";
# const CARD_BG = "F4F7FC";
#
# let pres = new pptxgen();
# pres.layout = "LAYOUT_WIDE"; // 13.33 x 7.5
# const PGW = 13.33;
# const PGH = 7.5;
#
# // ---------- helpers ----------
# function header(slide, title) {
#   slide.background = { color: WHITE };
#   slide.addShape("rect", { x: 0, y: 0, w: PGW, h: 0.85, fill: { color: NAVY } });
#   slide.addText("unilog", { x: 0.35, y: 0.18, w: 1.1, h: 0.5, fontSize: 20, bold: true, color: WHITE, fontFace: "Arial" });
#   slide.addText("H2S", { x: 1.55, y: 0.18, w: 0.9, h: 0.5, fontSize: 18, bold: true, color: BLUE_LIGHT, fontFace: "Arial" });
#   slide.addText([
#     { text: "Uni", options: { color: BLUE_LIGHT, bold: true } },
#     { text: "Hack", options: { color: WHITE, bold: true } }
#   ], { x: PGW - 2.4, y: 0.18, w: 2.0, h: 0.5, fontSize: 20, fontFace: "Arial", align: "right" });
#   slide.addShape("rect", { x: 0, y: PGH - 0.12, w: PGW, h: 0.12, fill: { color: BLUE } });
#   if (title) {
#     slide.addText(title, { x: 0.5, y: 1.0, w: PGW - 1.0, h: 0.55, fontSize: 22, bold: false, color: "1A1A1A", fontFace: "Arial", valign: "top" });
#   }
# }
#
# function bodyBox(x, y, w, h) {
#   return { x, y, w, h };
# }
#
# // ================= SLIDE 1 — Title =================
# {
#   let s = pres.addSlide();
#   s.background = { color: NAVY_DARK };
#   s.addShape("rect", { x: 0, y: 0, w: PGW, h: 0.85, fill: { color: NAVY } });
#   s.addText("unilog", { x: 0.35, y: 0.18, w: 1.1, h: 0.5, fontSize: 20, bold: true, color: WHITE, fontFace: "Arial" });
#   s.addText("H2S", { x: 1.55, y: 0.18, w: 0.9, h: 0.5, fontSize: 18, bold: true, color: BLUE_LIGHT, fontFace: "Arial" });
#   s.addText([
#     { text: "Uni", options: { color: BLUE_LIGHT, bold: true } },
#     { text: "Hack", options: { color: WHITE, bold: true } }
#   ], { x: PGW - 2.4, y: 0.18, w: 2.0, h: 0.5, fontSize: 20, fontFace: "Arial", align: "right" });
#
#   s.addText([
#     { text: "Catalog", options: { color: BLUE_LIGHT, bold: true } },
#     { text: "IQ", options: { color: WHITE, bold: true } }
#   ], { x: 0.7, y: 2.1, w: 9, h: 1.4, fontSize: 60, fontFace: "Arial" });
#
#   s.addText("AI-Powered Product Intelligence for", { x: 0.75, y: 3.55, w: 9, h: 0.5, fontSize: 20, color: WHITE, fontFace: "Arial" });
#   s.addText("Industrial Commerce", { x: 0.75, y: 4.0, w: 9, h: 0.5, fontSize: 20, bold: true, color: BLUE_LIGHT, fontFace: "Arial" });
#
#   s.addText("UniHack Prototype Submission", { x: 0.75, y: 5.0, w: 6, h: 0.4, fontSize: 14, color: "AFC6E8", italic: true, fontFace: "Arial" });
#
#   // decorative concentric arcs (subtle, echoes template art without copying it)
#   for (let i = 0; i < 4; i++) {
#     const r = 1.6 + i * 0.55;
#     s.addShape("ellipse", { x: 9.6 - r, y: 3.75 - r, w: r * 2, h: r * 2, fill: { type: "none" }, line: { color: BLUE_LIGHT, width: 1, transparency: 55 } });
#   }
#   s.addShape("ellipse", { x: 9.4, y: 3.55, w: 0.4, h: 0.4, fill: { color: BLUE_LIGHT } });
#
#   s.addShape("rect", { x: 0, y: PGH - 0.12, w: PGW, h: 0.12, fill: { color: BLUE } });
# }
#
# // ================= SLIDE 2 — Team Details =================
# {
#   let s = pres.addSlide();
#   header(s, null);
#   s.addText("Team Details", { x: 0.5, y: 1.1, w: 8, h: 0.6, fontSize: 26, bold: true, color: NAVY, fontFace: "Arial" });
#
#   const rows = [
#     ["Team name:", "SoloForge AI"],
#     ["Team leader / member:", "Lasya"],
#     ["Team size:", "1 (solo participant)"],
#     ["Track:", "AI-Powered Product Intelligence for Industrial Commerce"]
#   ];
#   let y = 2.1;
#   rows.forEach((r) => {
#     s.addText(r[0], { x: 0.9, y, w: 3.4, h: 0.5, fontSize: 16, bold: true, color: GRAY_TEXT, fontFace: "Arial" });
#     s.addText(r[1], { x: 4.4, y, w: 7.5, h: 0.5, fontSize: 16, color: GRAY_TEXT, fontFace: "Arial" });
#     y += 0.65;
#   });
# }
#
# // ================= SLIDE 3 — Brief about solution =================
# {
#   let s = pres.addSlide();
#   header(s, "Brief about your solution");
#   s.addText(
#     "CatalogIQ is an AI pipeline that turns sparse industrial part data — often just a Part Number, Brand, and a short description — into complete, verified product intelligence: technical specifications, categorization, compliance data, images, and cross-references. Every generated attribute carries a confidence score and a source trail, so distributors can trust and scale enrichment across catalogs with millions of SKUs without a proportional increase in manual review effort.",
#     { x: 0.5, y: 1.75, w: PGW - 1.0, h: 1.6, fontSize: 16, color: GRAY_TEXT, fontFace: "Arial", valign: "top", lineSpacingMultiple: 1.25 }
#   );
#
#   const cards = [
#     { t: "Input", d: "Part #, Brand,\nshort description" },
#     { t: "Enrich", d: "Multi-source AI\nextraction & reasoning" },
#     { t: "Validate", d: "Confidence scoring +\nhuman review" },
#     { t: "Deliver", d: "Rich, trusted\nproduct record" }
#   ];
#   const cw = 2.75, gap = 0.28, startX = 0.5;
#   cards.forEach((c, i) => {
#     const x = startX + i * (cw + gap);
#     s.addShape("roundRect", { x, y: 3.75, w: cw, h: 1.7, rectRadius: 0.08, fill: { color: CARD_BG }, line: { color: "DCE4F0", width: 1 } });
#     s.addText(c.t, { x: x + 0.15, y: 3.9, w: cw - 0.3, h: 0.4, fontSize: 16, bold: true, color: NAVY, fontFace: "Arial" });
#     s.addText(c.d, { x: x + 0.15, y: 4.35, w: cw - 0.3, h: 1.0, fontSize: 12.5, color: LGRAY, fontFace: "Arial", valign: "top" });
#     if (i < cards.length - 1) {
#       s.addText("\u2192", { x: x + cw, y: 4.3, w: gap, h: 1.0, fontSize: 20, color: BLUE, align: "center", fontFace: "Arial" });
#     }
#   });
#
#   s.addText(
#     "Built for industrial distributors and manufacturers who receive incomplete supplier feeds and need enterprise-grade product data without a large manual data-entry team.",
#     { x: 0.5, y: 5.75, w: PGW - 1.0, h: 0.6, fontSize: 12.5, italic: true, color: LGRAY, fontFace: "Arial" }
#   );
# }
#
# // ================= SLIDE 4 — Q1 Enrichment =================
# {
#   let s = pres.addSlide();
#   header(s, "1. How does your solution enrich minimal product information?");
#   s.addText(
#     "CatalogIQ transforms a bare Part Number, Brand, and short description into a full product record through a four-stage AI pipeline:",
#     { x: 0.5, y: 1.72, w: PGW - 1.0, h: 0.6, fontSize: 14, color: GRAY_TEXT, fontFace: "Arial" }
#   );
#
#   const items = [
#     ["Entity extraction", "NER model parses the input to identify brand, part family, and any embedded specs (e.g., size, voltage, material codes hidden in the part number)."],
#     ["Multi-source retrieval (RAG)", "Retrieves candidate matches from manufacturer datasheets, distributor feeds, and industry standards databases via a retrieval-augmented LLM."],
#     ["Structured attribute generation", "The LLM extracts dimensions, materials, certifications, compatible/substitute parts, and writes an SEO-friendly long description."],
#     ["Taxonomy mapping", "Auto-tags the product into the correct category tree so it slots directly into the client's existing catalog structure."]
#   ];
#   let y = 2.45;
#   items.forEach((it) => {
#     s.addShape("ellipse", { x: 0.6, y: y + 0.08, w: 0.16, h: 0.16, fill: { color: BLUE } });
#     s.addText(it[0], { x: 0.95, y, w: 3.3, h: 0.9, fontSize: 14.5, bold: true, color: NAVY, fontFace: "Arial", valign: "top" });
#     s.addText(it[1], { x: 4.35, y, w: PGW - 4.85, h: 0.9, fontSize: 13.5, color: GRAY_TEXT, fontFace: "Arial", valign: "top" });
#     y += 1.05;
#   });
# }
#
# // ================= SLIDE 5 — Q2 Accuracy & Trust =================
# {
#   let s = pres.addSlide();
#   header(s, "2. How does your solution ensure accuracy and trust?");
#   s.addText(
#     "Trust is built into every generated field, not bolted on afterward. CatalogIQ layers six validation mechanisms:",
#     { x: 0.5, y: 1.72, w: PGW - 1.0, h: 0.5, fontSize: 14, color: GRAY_TEXT, fontFace: "Arial" }
#   );
#
#   const boxes = [
#     ["Confidence Scoring", "Every attribute gets a 0-100% score based on cross-source agreement and model certainty."],
#     ["Multi-Source Verification", "Cross-checks manufacturer PDFs, distributor feeds, and standards databases before accepting a value."],
#     ["Rule-Based Validation", "Category-specific rules check units, ranges, and formats (e.g., voltage within valid bounds)."],
#     ["AI Critic Pass", "A second LLM pass reviews the first pass's output and flags internal contradictions."],
#     ["Human-in-the-Loop", "Low-confidence fields route to a reviewer queue for quick approve / edit before publishing."],
#     ["Source Citation Trail", "Every field links back to the exact document/source it was derived from, for auditability."]
#   ];
#   const cols = 3, rows = 2, cw = 4.0, ch = 1.7, gx = 0.15, gy = 0.18, startX = 0.5, startY = 2.35;
#   boxes.forEach((b, i) => {
#     const col = i % cols, row = Math.floor(i / cols);
#     const x = startX + col * (cw + gx), y = startY + row * (ch + gy);
#     s.addShape("roundRect", { x, y, w: cw, h: ch, rectRadius: 0.07, fill: { color: CARD_BG }, line: { color: "DCE4F0", width: 1 } });
#     s.addText(b[0], { x: x + 0.18, y: y + 0.13, w: cw - 0.36, h: 0.4, fontSize: 14, bold: true, color: NAVY, fontFace: "Arial" });
#     s.addText(b[1], { x: x + 0.18, y: y + 0.55, w: cw - 0.36, h: ch - 0.7, fontSize: 11.5, color: GRAY_TEXT, fontFace: "Arial", valign: "top" });
#   });
# }
#
# // ================= SLIDE 6 — Q3 Scalability =================
# {
#   let s = pres.addSlide();
#   header(s, "3. What makes your solution scalable for enterprise catalogs?");
#
#   const items = [
#     ["Large catalogs", "Async, queue-based batch workers (Redis/BullMQ) process enrichment jobs in parallel and scale horizontally with catalog volume."],
#     ["New manufacturers", "Manufacturer-agnostic ingestion: configurable extraction templates for known brands, with LLM fallback for unseen ones — no re-engineering per brand."],
#     ["Different document formats", "Modular parser adapters handle PDF, Excel, XML/EDI feeds, and scanned documents (OCR via Tesseract) through one unified pipeline."],
#     ["Continuous updates", "Delta processing re-enriches only changed fields; a vector DB detects near-duplicate parts across catalogs to avoid redundant work."]
#   ];
#   let y = 1.8;
#   items.forEach((it) => {
#     s.addShape("roundRect", { x: 0.5, y, w: PGW - 1.0, h: 1.1, rectRadius: 0.06, fill: { color: CARD_BG }, line: { color: "DCE4F0", width: 1 } });
#     s.addText(it[0], { x: 0.75, y: y + 0.1, w: 3.0, h: 0.9, fontSize: 15, bold: true, color: NAVY, fontFace: "Arial", valign: "top" });
#     s.addText(it[1], { x: 3.9, y: y + 0.1, w: PGW - 4.6, h: 0.9, fontSize: 12.5, color: GRAY_TEXT, fontFace: "Arial", valign: "top" });
#     y += 1.28;
#   });
# }
#
# // ================= SLIDE 7 — Opportunities =================
# {
#   let s = pres.addSlide();
#   header(s, "Opportunities");
#
#   s.addText("a. How different is it from existing ideas?", { x: 0.6, y: 1.75, w: PGW - 1.2, h: 0.4, fontSize: 15.5, bold: true, color: NAVY, fontFace: "Arial" });
#   s.addText(
#     "Most PIM enrichment tools rely on single-source scraping or static manual templates. CatalogIQ layers multi-source AI verification with per-field confidence scoring, routing only uncertain fields to human reviewers — cutting manual review effort by an estimated 70-80% versus template-based tools.",
#     { x: 0.9, y: 2.13, w: PGW - 1.5, h: 0.75, fontSize: 13, color: GRAY_TEXT, fontFace: "Arial", valign: "top" }
#   );
#
#   s.addText("b. How does it solve the problem statement?", { x: 0.6, y: 3.05, w: PGW - 1.2, h: 0.4, fontSize: 15.5, bold: true, color: NAVY, fontFace: "Arial" });
#   s.addText(
#     "It directly automates the transformation of minimal supplier inputs into rich, trustworthy product intelligence, at a scale that matches enterprise industrial catalogs — the exact challenge the brief describes.",
#     { x: 0.9, y: 3.43, w: PGW - 1.5, h: 0.6, fontSize: 13, color: GRAY_TEXT, fontFace: "Arial", valign: "top" }
#   );
#
#   s.addText("c. USP of the proposed solution", { x: 0.6, y: 4.2, w: PGW - 1.2, h: 0.4, fontSize: 15.5, bold: true, color: NAVY, fontFace: "Arial" });
#   s.addText(
#     "A confidence-scored, multi-source-verified enrichment pipeline that is manufacturer-agnostic and self-improving — reviewer corrections feed back into the extraction model, so accuracy compounds over time instead of staying static.",
#     { x: 0.9, y: 4.58, w: PGW - 1.5, h: 0.75, fontSize: 13, color: GRAY_TEXT, fontFace: "Arial", valign: "top" }
#   );
# }
#
# // ================= SLIDE 8 — Features =================
# {
#   let s = pres.addSlide();
#   header(s, "List of features offered by the solution");
#
#   const feats = [
#     "Bulk CSV/Excel upload & single-item API input",
#     "Automated attribute extraction (specs, dimensions, materials, certifications)",
#     "AI-generated long-form descriptions & SEO tags",
#     "Per-field confidence score dashboard",
#     "Multi-source citation trail for every attribute",
#     "Cross-reference / substitute part finder",
#     "Human review queue with inline edit & approve",
#     "Format-agnostic ingestion: PDF, XML/EDI, Excel, scanned docs (OCR)",
#     "Automatic category & taxonomy tagging",
#     "REST API + webhooks for catalog system integration",
#     "Analytics dashboard: enrichment coverage & accuracy trends",
#     "Duplicate / near-duplicate part detection via vector search"
#   ];
#   const cols = 2, gx = 0.4, startX = 0.6, startY = 1.85, rowH = 0.62, colW = (PGW - 1.2 - gx) / 2;
#   feats.forEach((f, i) => {
#     const col = i % cols, row = Math.floor(i / cols);
#     const x = startX + col * (colW + gx), y = startY + row * rowH;
#     s.addShape("ellipse", { x, y: y + 0.09, w: 0.14, h: 0.14, fill: { color: BLUE } });
#     s.addText(f, { x: x + 0.32, y: y - 0.05, w: colW - 0.32, h: 0.55, fontSize: 13, color: GRAY_TEXT, fontFace: "Arial", valign: "top" });
#   });
# }
#
# // ================= SLIDE 9 — Process Flow Diagram =================
# {
#   let s = pres.addSlide();
#   header(s, "Process flow diagram");
#
#   const steps = [
#     "Supplier\nInput",
#     "Entity\nExtraction (NER)",
#     "Multi-Source\nRetrieval (RAG)",
#     "Attribute\nGeneration",
#     "Validation &\nConfidence Score"
#   ];
#   const n = steps.length, boxW = 2.05, boxH = 1.1, gap = (PGW - 1.0 - n * boxW) / (n - 1);
#   let x0 = 0.5, y0 = 1.95;
#   steps.forEach((t, i) => {
#     const x = x0 + i * (boxW + gap);
#     s.addShape("roundRect", { x, y: y0, w: boxW, h: boxH, rectRadius: 0.08, fill: { color: i === n - 1 ? BLUE : CARD_BG }, line: { color: BLUE, width: 1.25 } });
#     s.addText(t, { x: x + 0.05, y: y0, w: boxW - 0.1, h: boxH, fontSize: 12.5, bold: true, color: i === n - 1 ? WHITE : NAVY, align: "center", valign: "middle", fontFace: "Arial" });
#     if (i < n - 1) {
#       s.addText("\u2192", { x: x + boxW, y: y0, w: gap, h: boxH, fontSize: 22, color: BLUE, align: "center", valign: "middle", fontFace: "Arial" });
#     }
#   });
#
#   // branch down to human review
#   s.addShape("line", { x: x0 + 3 * (boxW + gap) + boxW / 2, y: y0 + boxH, w: 0, h: 0.55, line: { color: LGRAY, width: 1.25, dashType: "dash" } });
#   s.addShape("roundRect", { x: x0 + 3 * (boxW + gap) + boxW / 2 - 1.15, y: y0 + boxH + 0.55, w: 2.3, h: 0.75, rectRadius: 0.08, fill: { color: "FFF3D6" }, line: { color: "E0AE2E", width: 1 } });
#   s.addText("Low-confidence \u2192 Human Review", { x: x0 + 3 * (boxW + gap) + boxW / 2 - 1.15, y: y0 + boxH + 0.55, w: 2.3, h: 0.75, fontSize: 10.5, bold: true, color: "8A6300", align: "center", valign: "middle", fontFace: "Arial" });
#
#   s.addShape("line", { x: x0 + 4 * (boxW + gap) + boxW / 2, y: y0 + boxH, w: 0, h: 1.2, line: { color: BLUE, width: 1.25 } });
#   s.addShape("roundRect", { x: x0 + 4 * (boxW + gap) + boxW / 2 - 1.4, y: y0 + boxH + 1.2, w: 2.8, h: 0.75, rectRadius: 0.08, fill: { color: NAVY }, line: { color: NAVY, width: 1 } });
#   s.addText("Enriched Product Record\n(published to catalog)", { x: x0 + 4 * (boxW + gap) + boxW / 2 - 1.4, y: y0 + boxH + 1.2, w: 2.8, h: 0.75, fontSize: 11, bold: true, color: WHITE, align: "center", valign: "middle", fontFace: "Arial" });
#
#   s.addText("Use case: a distributor uploads a supplier feed with only Part #, Brand, and a one-line description; CatalogIQ returns a complete, review-ready product record.", { x: 0.5, y: 6.35, w: PGW - 1.0, h: 0.5, fontSize: 12, italic: true, color: LGRAY, fontFace: "Arial" });
# }
#
# // ================= SLIDE 10 — Wireframes (optional) =================
# {
#   let s = pres.addSlide();
#   header(s, "Wireframes / Mock diagrams of the proposed solution");
#
#   // Wireframe: enrichment review dashboard
#   const wx = 0.7, wy = 1.85, ww = 7.6, wh = 4.6;
#   s.addShape("roundRect", { x: wx, y: wy, w: ww, h: wh, rectRadius: 0.05, fill: { color: WHITE }, line: { color: "C9D3E3", width: 1.25 } });
#   s.addShape("rect", { x: wx, y: wy, w: ww, h: 0.5, fill: { color: NAVY } });
#   s.addText("CatalogIQ \u2014 Enrichment Review", { x: wx + 0.2, y: wy, w: 5, h: 0.5, fontSize: 12, bold: true, color: WHITE, valign: "middle", fontFace: "Arial" });
#   s.addShape("roundRect", { x: wx + ww - 1.6, y: wy + 0.1, w: 1.35, h: 0.3, rectRadius: 0.15, fill: { color: BLUE } });
#   s.addText("Upload", { x: wx + ww - 1.6, y: wy + 0.1, w: 1.35, h: 0.3, fontSize: 9, color: WHITE, align: "center", valign: "middle", fontFace: "Arial" });
#
#   const tableY = wy + 0.75;
#   const headers = ["Part #", "Field", "AI Value", "Confidence", "Action"];
#   const colW = [1.15, 1.35, 2.5, 1.4, 1.2];
#   let cx = wx + 0.2;
#   headers.forEach((h, i) => {
#     s.addText(h, { x: cx, y: tableY, w: colW[i], h: 0.3, fontSize: 9.5, bold: true, color: NAVY, fontFace: "Arial" });
#     cx += colW[i];
#   });
#   s.addShape("line", { x: wx + 0.15, y: tableY + 0.32, w: ww - 0.3, h: 0, line: { color: "DCE4F0", width: 1 } });
#
#   const rowsData = [
#     ["PN-4471", "Material", "304 Stainless Steel", "96%", "\u2713 OK"],
#     ["PN-4471", "Voltage", "24V DC", "88%", "\u2713 OK"],
#     ["PN-4471", "Certification", "UL, CE", "61%", "Review"],
#     ["PN-8823", "Dimension", "50 x 50 x 12 mm", "93%", "\u2713 OK"],
#     ["PN-8823", "Substitute Part", "PN-8824-B", "54%", "Review"]
#   ];
#   let ry = tableY + 0.45;
#   rowsData.forEach((row) => {
#     let cx2 = wx + 0.2;
#     row.forEach((val, i) => {
#       let color = GRAY_TEXT;
#       let bold = false;
#       if (i === 3) {
#         const pct = parseInt(val);
#         color = pct >= 80 ? "1E8E3E" : "B8860B";
#         bold = true;
#       }
#       if (i === 4 && val === "Review") { color = "B8860B"; bold = true; }
#       if (i === 4 && val.includes("OK")) { color = "1E8E3E"; bold = true; }
#       s.addText(val, { x: cx2, y: ry, w: colW[i], h: 0.4, fontSize: 9.5, color, bold, fontFace: "Arial" });
#       cx2 += colW[i];
#     });
#     ry += 0.5;
#   });
#   s.addShape("roundRect", { x: wx + 0.2, y: wy + wh - 0.55, w: 1.7, h: 0.32, rectRadius: 0.16, fill: { color: BLUE } });
#   s.addText("Approve All \u2265 90%", { x: wx + 0.2, y: wy + wh - 0.55, w: 1.7, h: 0.32, fontSize: 8.5, color: WHITE, align: "center", valign: "middle", fontFace: "Arial" });
#
#   // side panel: confidence summary
#   const px = wx + ww + 0.35, pw = PGW - px - 0.5;
#   s.addShape("roundRect", { x: px, y: wy, w: pw, h: wh, rectRadius: 0.05, fill: { color: CARD_BG }, line: { color: "C9D3E3", width: 1 } });
#   s.addText("Catalog Health", { x: px + 0.2, y: wy + 0.15, w: pw - 0.4, h: 0.35, fontSize: 12, bold: true, color: NAVY, fontFace: "Arial" });
#   const stats = [["Enriched SKUs", "128,430"], ["Avg. Confidence", "91.4%"], ["Pending Review", "1,206"], ["Sources Verified", "3.2 avg/SKU"]];
#   let sy = wy + 0.65;
#   stats.forEach((st) => {
#     s.addText(st[0], { x: px + 0.2, y: sy, w: pw - 0.4, h: 0.28, fontSize: 9.5, color: LGRAY, fontFace: "Arial" });
#     s.addText(st[1], { x: px + 0.2, y: sy + 0.26, w: pw - 0.4, h: 0.35, fontSize: 15, bold: true, color: NAVY, fontFace: "Arial" });
#     sy += 0.78;
#   });
#
#   s.addText("Conceptual wireframe \u2014 review dashboard where reviewers approve/edit low-confidence AI-generated fields.", { x: 0.7, y: wy + wh + 0.15, w: PGW - 1.4, h: 0.4, fontSize: 11.5, italic: true, color: LGRAY, fontFace: "Arial" });
# }
#
# // ================= SLIDE 11 — Archit
# Out:
# Writing CatalogIQ_UniHack_ppt_generator.js
